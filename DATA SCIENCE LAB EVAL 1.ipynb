# %% [markdown]
# CB.EN.U4CSE20265
#
# DATA SCIENCE EVALUATION 1

# %% [markdown]
# q1

# %%
import pandas as pd
link ="/content/Absenteism_at_work2.csv"
df65=pd.read_csv(link)
df65
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %% [markdown]
# q2

# %%
df = df65.drop(['Reason for absence','Body mass index','Pet','Weight','Height','Social smoker','Social drinker'],axis=1)
df
# Out:
#      ID  Month of absence  Day of the week  Seasons  Transportation expense  \
# 0    11                 7                3        1                     289
# 1    36                 7                3        1                     118
# 2     3                 7                4        1                     179
# 3     7                 7                5        1                     279
# 4    11                 7                5        1                     289
# ..   ..               ...              ...      ...                     ...
# 735  11                 7                3        1                     289
# 736   1                 7                3        1                     235
# 737   4                 0                3        1                     118
# 738   8                 0                4        2                     231
# 739  35                 0                6        3                     179
#
# ...

# %% [markdown]
# q3

# %%
for i in df65.columns:
  df65[i] = df65[i].fillna(df65[i].mode())
df65
# Out:
#      ID  Reason for absence
# 0    11                  26
# 1    36                   0
# 2     3                  23
# 3     7                   7
# 4    11                  23
# ..   ..                 ...
# 735  11                  14
# 736   1                  11
# 737   4                   0
# 738   8                   0
# 739  35                   0
#
# [740 rows x 2 columns]

# %% [markdown]
# q4

# %%
df65.boxplot("Seasons")
df65.boxplot("social smoker")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-2cafe504ccb1> in <module>
#       1 df65.boxplot("Seasons")
# ----> 2 df65.boxplot("social smoker")
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     520         layout=layout,
#     521         return_type=return_type,
# --> 522         **kwargs,
#     523     )
#     524
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     403         layout=layout,
#     404         return_type=return_type,
# --> 405         **kwds,
#     406     )
#     407     plt.draw_if_interactive()
#
# ...

# %% [markdown]
# q5

# %%
df65=df65.iloc[:,0:2]
df65.corr()
# Out:
#                           ID  Reason for absence
# ID                  1.000000           -0.064245
# Reason for absence -0.064245            1.000000

# %% [markdown]
# q6

# %%
df65.describe()
# Out:
#                ID  Reason for absence
# count  740.000000          740.000000
# mean    18.017568           19.216216
# std     11.021247            8.433406
# min      1.000000            0.000000
# 25%      9.000000           13.000000
# 50%     18.000000           23.000000
# 75%     28.000000           26.000000
# max     36.000000           28.000000

# %% [markdown]
# q7

# %%
df65.head(3)
# Out:
#    ID  Reason for absence
# 0  11                  26
# 1  36                   0
# 2   3                  23

# %% [markdown]
# q8

# %%
df65.tail(4)
# Out:
#      ID  Reason for absence
# 736   1                  11
# 737   4                   0
# 738   8                   0
# 739  35                   0

# %% [markdown]
# q9

# %%
print(df65.iloc[65])
# Out:
# ID                    22
# Reason for absence    23
# Name: 65, dtype: int64

# %% [markdown]
# q10

# %%
len(df65.index)
df65
# Out:
#      ID  Reason for absence
# 0    11                  26
# 1    36                   0
# 2     3                  23
# 3     7                   7
# 4    11                  23
# ..   ..                 ...
# 735  11                  14
# 736   1                  11
# 737   4                   0
# 738   8                   0
# 739  35                   0
#
# [740 rows x 2 columns]

# %% [markdown]
# q11

# %%
df65.iloc[0:2,0:5]
# Out:
#    ID  Reason for absence
# 0  11                  26
# 1  36                   0

# %% [markdown]
# q12

# %%
df65 = data[data['Reason for absence'] == 9]
df65.groupby('Reason for absence').count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-afef155f6a79> in <module>
# ----> 1 df65 = data[data['Reason for absence'] == 9]
#       2 df65.groupby('Reason for absence').count()
#
# NameError: name 'data' is not defined

# %% [markdown]
# q13

# %% [markdown]
# q14

# %% [markdown]
# q15

# %% [markdown]
# q16

# %% [markdown]
# q17
